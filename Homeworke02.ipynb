# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny000327/Data_Structure/blob/main/Homeworke02.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. class Stack 정의 
class Stack:
  def __init__(self):
    self.items = []           # 데이터 저장을 위한 리스트 준비
  
  def push(self, val): 
    self.items.append(val)

  def pop(self): 
    try:
      return self.items.pop()  # pop할 아이템이 없으면 
    except IndexError:         # indexError 발생
      print("Stack is empty")

  def top(self): 
    try:
      return self.items[-1] 
    except IndexError:
      print("Stack is empty")

  def __len__(self):            # len()로 호출하면 stack의 item 수 반환
    return len(self.items)
  
  def isEmpty(self): 
    return self.__len__() == 0
  
# 2. get_token_list 함수 정의 
def get_token_list(expr):
  expr = expr.replace(' ', '')
  return expr

# 3. compute_postfix 함수 정의 
def compute_postfix(token_list):
  sk = Stack()
  for one in token_list:
    # 연산자이면
    if one in '+-/*^':
      n1 = sk.items.pop()
      n2 = sk.items.pop()
      if one == '+':
        sk.push(float(n2) + float(n1))
      elif one == '-':
        sk.push(float(n2) - float(n1))
      elif one == '/':
        sk.push(float(n2) / float(n1))
      elif one == '*':
        sk.push(float(n2) * float(n1))
      elif one == '^':
        sk.push(float(n2) ** float(n1))
    # 피연산자이면 
    else:
      sk.push(one)

  if sk.isEmpty():
    return 'None'
  return sk.top()


# 4. infix_to_postfix 함수 정의 
def infix_to_postfix(token_list):
  opstack = Stack() # 괄호와 연산자 저장 
  outstack = []  # postfix 수식 
  
  token_list = []
  j = 0 
  for i in range(len(token_list)):
    if token_list[i] in '+-/*^()':
      if i != j:
        token_list.append(token_list[j:i])
      token_list.append(token_list[i])
      j = i+1

  if j <= i:
    token_list.append(token_list[j])

  # 연산자의 우선순위 설정 
  prec = {}
  prec['('] = 0 
  prec['+'] = 1
  prec['-'] = 1
  prec['*'] = 2  
  prec['/'] = 2 
  prec['^'] = 3 

  for token in token_list:
    if token == '(': # 우선순위 젤 낮음 : 닫힌괄호나와야 출력되도록하기위함 
      opstack.push(token)
    elif token == ')':
      while not opstack.isEmpty():
        x = opstack.pop()
        if x == '(':
          break
        outstack.append(x)
      else:
          raise ValueError("괄호가 맞지 않습니다.")
    elif token in '+-/*^':
      # opstack에 있는 자신보다 우선순위가 높거나 같은 연산자는
      #  차례로 모두 pop한 후 outstack에 append함 
      while not opstack.isEmpty():
        x = opstack.top()
        if x is not None and prec[x] >= prec[token]: 
          outstack.append(opstack.pop())
        else:
          break
      opstack.push(token)
    else: # 피연산자 
      outstack.append(token)

  while not opstack.isEmpty():
    outstack.append(opstack.pop())
  
  return outstack



# __main__
expr = input()
# expr = '3+ 2* 4/(6- 1)'
# expr = '3.14*2.10/(10.2-21)'
# expr = '6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2'
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 3+ 2* 4/(6- 1)
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-6-8f49aa195a97> in <module>
#     119 # expr = '3.14*2.10/(10.2-21)'
#     120 # expr = '6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2'
# --> 121 value = compute_postfix(infix_to_postfix(get_token_list(expr)))
#     122 print(value)
#
# <ipython-input-6-8f49aa195a97> in infix_to_postfix(token_list)
#      71       j = i+1
#      72
# ---> 73   if j <= i:
#      74     token_list.append(token_list[j])
#      75
#
# UnboundLocalError: local variable 'i' referenced before assignment

# %%
# 1. class Stack 정의 
class Stack:
  def __init__(self):
    self.items = []           # 데이터 저장을 위한 리스트 준비
  
  def push(self, val): 
    self.items.append(val)

  def pop(self): 
    try:
      return self.items.pop()  # pop할 아이템이 없으면 
    except IndexError:         # indexError 발생
      print("Stack is empty")

  def top(self): 
    try:
      return self.items[-1] 
    except IndexError:
      print("Stack is empty")

  def __len__(self):            # len()로 호출하면 stack의 item 수 반환
    return len(self.items)
  
  def isEmpty(self): 
    return self.__len__() == 0
  
# 2. get_token_list 함수 정의 
def get_token_list(expr):
  expr = expr.replace(' ', '')
  return expr

# 3. compute_postfix 함수 정의 
def compute_postfix(postfix):
  sk = Stack()
  for one in postfix:
    # 연산자이면
    if one in '+-/*^':
      n1 = sk.items.pop()
      n2 = sk.items.pop()
      if one == '+':
        sk.push(float(n2) + float(n1))
      elif one == '-':
        sk.push(float(n2) - float(n1))
      elif one == '/':
        sk.push(float(n2) / float(n1))
      elif one == '*':
        sk.push(float(n2) * float(n1))
      elif one == '^':
        sk.push(float(n2) ** float(n1))
    # 피연산자이면 
    else:
      sk.push(one)

  if sk.isEmpty():
    return 'None'
  return sk.top()


# 4. infix_to_postfix 함수 정의 
def infix_to_postfix(infix):
  opstack = Stack() # 괄호와 연산자 저장 
  outstack = []  # postfix 수식 
  
  token_list = []
  j = 0 
  for i in range(len(infix)):
    if infix[i] in '+-/*^()':
      if i != j:
        token_list.append(infix[j:i])
      token_list.append(infix[i])
      j = i+1

  if j <= i:
    token_list.append(infix[j])

  # 연산자의 우선순위 설정 
  prec = {}
  prec['('] = 0 
  prec['+'] = 1
  prec['-'] = 1
  prec['*'] = 2  
  prec['/'] = 2 
  prec['^'] = 3 

  for token in token_list:
    if token == '(': # 우선순위 젤 낮음 : 닫힌괄호나와야 출력되도록하기위함 
      opstack.push(token)
    elif token == ')':
      while not opstack.isEmpty():
        x = opstack.pop()
        if x == '(':
          break
        outstack.append(x)
      else:
        raise ValueError("괄호가 맞지 않습니다.")
    elif token in '+-/*^':
      while not opstack.isEmpty():
        x = opstack.top()
        if x is not None and prec[x] >= prec[token]: 
          outstack.append(opstack.pop())
        else:
          break
      opstack.push(token)
    else: # 피연산자 
      outstack.append(token)

  while not opstack.isEmpty():
    outstack.append(opstack.pop())
  
  return outstack



# __main__
expr = input()
# expr = '3+ 2* 4/(6- 1)'
# expr = '3.14*2.10/(10.2-21)'
# expr = '6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2'
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 3+ 2* 4/(6- 1)
# 4.6

# %%
class Stack:
	def __init__(self):
		self.items = [] #데이터 저장을 위한 리스트 준비
	
	def push(self, val):
		self.items.append(val)
		
	def pop(self):
		try:
			return self.items.pop() #pop할 아이템이 없으면
		except IndexError:				#indexError 발생
			print("Stack is empty")
	
	def top(self):
		try:
			return self.items[-1]
		except IndexError:
			print("Stack is empty")
	
	def __len__(self):					#len()로 호출하면 stack의 item 수 반환
		return len(self.items)
	
	def isEmpty(self):
		return self.__len__() == 0
	
	
#1 get_token_list 함수 정의
def get_token_list(expr):
	expr = expr.replace(' ', '')
	return expr
	
#3 compute_postfix 함수 정의
def compute_postfix(postfix):
	sk = Stack()
	for one in postfix:
		if one in '+-/*^': #연산자면
			n1 = sk.items.pop()
			n2 = sk.items.pop()
			if one == '+':
				sk.push(float(n2) + float(n1))
			elif one == '-':
				sk.push(float(n2) - float(n1))
			elif one == '/':
				sk.push(float(n2) / float(n1))
			elif one == '*':
				sk.push(float(n2) * float(n1))
			elif one == '^':
				sk.push(float(n2) ** float(n1))
				
		else: #피연산자면
			sk.push(one)
			
	if sk.isEmpty():
		return 'None'
	return sk.top()
	
	
#2 infix_to_postfix 함수 정의
def infix_to_postfix(infix):
	opstack = Stack()
	outstack = []
	
	token_list = []
	j = 0
	for i in range(len(infix)):
		if infix[i]in '+-/*^()':
			if i != j:
				token_list.append(infix[j:i])
			token_list.append(infix[i])
			j = i + 1
			
	if j <= i:
		token_list.append(infix[j])
		
	prec = {} #연산자 우선순위
	prec['('] = 0
	prec['+'] = 1
	prec['-'] = 1
	prec['*'] = 2
	prec['/'] = 2
	prec['^'] = 3
	
	for token in token_list:
		if token == '(': #우선순위 젤 낮음. 닫힌 괄호 나와야 출력되도록 하기 위함.
			opstack.push(token)
		elif token == ')':
			while not opstack.isEmpty():
				x = opstack.pop()
				if x == '(':
					break
				outstack.append(x)
			else:
				raise ValueError("괄호가 맞지 않습니다.")
		elif token in '+-/*^':
			while not opstack.isEmpty():
				x = opstack.top()
				if x is not None and prec[x] >= prec[token]:
					outstack.append(opstack.pop())
				else:
					break
			opstack.push(token)
		else: #피연산자
			outstack.append(token)
		
	while not opstack.isEmpty():
		outstack.append(opstack.pop())
			
	return outstack
	
# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)

# %%
# 1. class Stack 정의 
class Stack:
  def __init__(self):
    self.items = []           # 데이터 저장을 위한 리스트 준비
  
  def push(self, val): 
    self.items.append(val)

  def pop(self): 
    try:
      return self.items.pop()  # pop할 아이템이 없으면 
    except IndexError:         # indexError 발생
      print("Stack is empty")

  def top(self): 
    try:
      return self.items[-1] 
    except IndexError:
      print("Stack is empty")

  def __len__(self):            # len()로 호출하면 stack의 item 수 반환
    return len(self.items)
  
  def isEmpty(self): 
    return self.__len__() == 0
  
# 2. get_token_list 함수 정의 
def get_token_list(expr):
  expr = expr.replace(' ', '')
  token_list = expr.split()
  return token_list


# 4. infix_to_postfix 함수 정의 
def infix_to_postfix(infix):
  opstack = Stack() # 괄호와 연산자 저장 
  outstack = []  # postfix 수식 
  
  # 연산자의 우선순위 설정 
  prec = {}
  prec['('] = 0 
  prec['+'] = 1
  prec['-'] = 1
  prec['*'] = 2  
  prec['/'] = 2 
  prec['^'] = 3 
  prec[')'] = 4 #닫힘 괄호 우선순위를 지정정

  for token in infix:
    if token == '(': # 우선순위 젤 낮음 : 닫힌괄호나와야 출력되도록하기위함 
      opstack.push(token)
    elif token == ')':
      while opstack.top() != '(':
          x = opstack.top()
          opstack.pop()
          outstack.append(x)
      opstack.pop()
    elif token in '+-/*^':
      if len(opstack) == 0:
          opstack.push(token)
      else:
        if opstack.top() == '(':
            opstack.push(token)
        else:
            if prec.get(token) <= prec.get((opstack.top())):
                while prec.get(token) <= prec.get((opstack.top())):
                    y = opstack.top()
                    opstack.pop()
                    outstack.append(y)
                    if len(opstack) == 0:
                        break
                opstack.push(token)
            else:
                opstack.push(token)
    else: # 피연산자 
      outstack.append(token)

  if len(opstack) != 0:
    for i in range(len(opstack),0,-1):
        z = opstack.top()
        opstack.pop()
        outstack.append(z)
  return outstack

# 3. compute_postfix 함수 정의 
def compute_postfix(postfix):
  sk = Stack()
  for one in postfix:
    # 연산자이면
    if one in '+-/*^':
      n1 = sk.items.pop()
      n2 = sk.items.pop()
      if one == '+':
        sk.push(float(n2) + float(n1))
      elif one == '-':
        sk.push(float(n2) - float(n1))
      elif one == '/':
        sk.push(float(n2) / float(n1))
      elif one == '*':
        sk.push(float(n2) * float(n1))
      elif one == '^':
        sk.push(float(n2) ** float(n1))
    # 피연산자이면 
    else:
      sk.push(one)

  if sk.isEmpty():
    return 'None'
  return sk.top()

# __main__
expr = input()
# expr = '3+ 2* 4/(6- 1)'
# expr = '3.14*2.10/(10.2-21)'
# expr = '6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2'
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2
# 6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2

# %%
class Stack:
	def __init__(self):
		self.items=[]

	def push(self,val):
		self.items.append(val)
  
	def pop(self):
		try:
			return self.items.pop()
		except IndexError:
			print('Stack is empty')
   
	def top(self):
		return self.items[-1]

	def __len__(self):
		return len(self.items)
  
	def isEmpty(self):
		return self.__len__() == 0
	
def get_token_list(expr):
	expr = expr.replace('+', ' + ').replace('-', ' - ').replace('*', ' * ').replace('/', ' / ').replace('^', ' ^ ').replace('(', ' ( ').replace(')',' ) ')
    #token_list = expr.split()
	return expr #token_list
	
def infix_to_postfix(infix):
    opstack = Stack()
    outstack = []
   
    token_list = []
    j = 0
    for i in range(len(infix)):
        if infix[i]in '+-/*^()':
            if i != j:
                token_list.append(infix[j:i])
            token_list.append(infix[i])
            j = i + 1
    if j <= i:
        token_list.append(infix[j])

	# 연산자의 우선순위 설정
    prec = {}
    prec['('] = 0
    prec['+'] = 1
    prec['-'] = 1
    prec['*'] = 2
    prec['/'] = 2
    prec['^'] = 3
    prec[')'] = 4
    for token in infix:
        if token == '(':
            opstack.push(token)
        elif token == ')':
            while opstack.top() != '(':
                x = opstack.top()
                opstack.pop()
                outstack.append(x)
            opstack.pop()
        elif token in '+-/*^':
			if len(opstack) == 0:
				opstack.push(token)
			else:
				if opstack.top() == '(':
					opstack.push(token)
				else:
					if prec.get(token) <= prec.get((opstack.top())):
						while prec.get(token) <= prec.get((opstack.top())):
							y = opstack.top()
							opstack.pop()
							outstack.append(y)
							if len(opstack) == 0:
								break
						opstack.push(token)
					else:
						opstack.push(token)
		else: # operand일 때
			outstack.append(token)

		# opstack 에 남은 모든 연산자를 pop 후 outstack에 append
    if len(opstack) != 0:
		for i in range(len(opstack),0,-1):
			z = opstack.top()
			opstack.pop()
			outstack.append(z)
	return outstack

def compute_postfix(token_list): #원래 token_list
	X = Stack()
	opstack = Stack()
	for token in token_list:
		if (token != '+') and (token != '-') and (token != '*') and (token != '/') and (token != '^'):
		#if (token in '+-*/^') == False:
			X.push(token)
		else:
			a = float(X.pop())
			b = float(X.pop())
			if token == '+':
				X.push(a+b)
			if token == '-':
				X.push(b-a)
			if token == '*':
			#print(X.pop())
				X.push(a*b)
			#print(X.pop())
			if token == '/':
				X.push(b/a)
			if token == '^':
				X.push(b**a)
	return X.top()
		#print(X.top())
# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
#   File "<tokenize>", line 83
#     if len(opstack) != 0:
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
class Stack:
	def __init__(self):
		self.items=[]

	def push(self,val):
		self.items.append(val)
  
	def pop(self):
		try:
			return self.items.pop()
		except IndexError:
			print('Stack is empty')
   
	def top(self):
		return self.items[-1]

	def __len__(self):
		return len(self.items)
  
	def isEmpty(self):
		return self.__len__() == 0
	
def get_token_list(expr):
	expr = expr.replace(' ', '')
	return expr

def infix_to_postfix(token_list):
	opstack = Stack()
	outstack = []

	# 연산자의 우선순위 설정
	prec = {}
	prec['('] = 0
	prec['+'] = 1
	prec['-'] = 1
	prec['*'] = 2
	prec['/'] = 2
	prec['^'] = 3
	prec[')'] = 4
	for token in token_list:	 
		if token == '(':
			opstack.push(token)
		elif token == ')':
			while opstack.top() != '(':
				x = opstack.top()
				opstack.pop()
				outstack.append(x)
			opstack.pop()
		elif token in '+-/*^':
			if len(opstack) == 0:
				opstack.push(token)
			else:
				if opstack.top() == '(':
					opstack.push(token)
				else:
					if prec.get(token) <= prec.get((opstack.top())):
						while prec.get(token) <= prec.get((opstack.top())):
							y = opstack.top()
							opstack.pop()
							outstack.append(y)
							if len(opstack) == 0:
								break
						opstack.push(token)
					else:
						opstack.push(token)
		else: # operand일 때
			outstack.append(token)

		# opstack 에 남은 모든 연산자를 pop 후 outstack에 append
	if len(opstack) != 0:
		for i in range(len(opstack),0,-1):
			z = opstack.top()
			opstack.pop()
			outstack.append(z)
	return outstack
 
def compute_postfix(postfix):
  sk = Stack()
  for one in postfix:
    if one not in '+-/*^':
      sk.push(one)
    else:
      n1 = sk.items.pop()
      n2 = sk.items.pop()
      if one == '+':
        sk.push(float(n2) + float(n1))
      elif one == '-':
        sk.push(float(n2) - float(n1))
      elif one == '/':
        sk.push(float(n2) / float(n1))
      elif one == '*':
        sk.push(float(n2) * float(n1))
      elif one == '^':
        sk.push(float(n2) ** float(n1))

  if sk.isEmpty():
    return 'None'
  return sk.top()

# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 6*4.5-18+3.3/3+2^3+(3-11.0*2+0.7)/2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-02b754921b32> in <module>
#     100 # 아래 세 줄은 수정하지 말 것!
#     101 expr = input()
# --> 102 value = compute_postfix(infix_to_postfix(get_token_list(expr)))
#     103 print(value)
#
# <ipython-input-17-02b754921b32> in compute_postfix(postfix)
#      90         sk.push(float(n2) / float(n1))
#      91       elif one == '*':
# ---> 92         sk.push(float(n2) * float(n1))
#      93       elif one == '^':
#      94         sk.push(float(n2) ** float(n1))
#
# ValueError: could not convert string to float: '.'

# %% [markdown]
# 정상 코드

# %%
class Stack:
	def __init__(self):
		self.items=[]

	def push(self,val):
		self.items.append(val)
  
	def pop(self):
		try:
			return self.items.pop()
		except IndexError:
			print('Stack is empty')
   
	def top(self):
		return self.items[-1]

	def __len__(self):
		return len(self.items)
  
	def isEmpty(self):
		return self.__len__() == 0
	
def get_token_list(expr):
	#expr = expr.replace('(', ' ( ').replace('+', ' + ').replace('-', ' - ').replace('*', ' * ').replace('/', ' / ').replace('^', ' ^ ').replace(')',' ) ')
	
    expr = expr.replace('(', ' ( ')
    expr = expr.replace(')', ' ) ')
    expr = expr.replace('+', ' + ')
    expr = expr.replace('-', ' - ')
    expr = expr.replace('*', ' * ')
    expr = expr.replace('/', ' / ')
    expr = expr.replace('^', ' ^ ')
    token_list = expr.split() #모든 연산자에 공백을 넣어놓고 공백으로 나누어 token_list만들기
    
    return token_list
	
def infix_to_postfix(token_list):
	opstack = Stack()
	outstack = []

	# 연산자의 우선순위 설정
	prec = {}
	prec['('] = 0
	prec['+'] = 1
	prec['-'] = 1
	prec['*'] = 2
	prec['/'] = 2
	prec['^'] = 3
	prec[')'] = 4 # 우선 순위 젤 낮음.

	for token in token_list:	 
		if token == '(':
			opstack.push(token)
		elif token == ')':
			while opstack.top() != '(':
				x = opstack.top()
				opstack.pop()
				outstack.append(x)
			opstack.pop()
		elif token in '+-/*^':
			if opstack.isEmpty():
				opstack.push(token)
			else:
				if opstack.top() == '(':
					opstack.push(token)
				else:
					if prec.get(token) <= prec.get((opstack.top())):
						while prec.get(token) <= prec.get((opstack.top())):
							opt = opstack.top()
							opstack.pop()
							outstack.append(opt)
							if opstack.isEmpty():
								break
						opstack.push(token)
					else:
						opstack.push(token)
		else: # operand일 때
			outstack.append(token)

# opstack 에 남은 모든 연산자를 pop 후 outstack에 append
	if not opstack.isEmpty():
		for i in range(len(opstack),0,-1): #남아있는 opstack 전체를
			opt = opstack.top() 
			opstack.pop()       # pop 하고 outstack에 append
			outstack.append(opt)
	return outstack

def compute_postfix(postfix): 
	sk = Stack()
	for token in postfix:
		if token in '+-/*^': #연산자면
			n1 = float(sk.pop())
			n2 = float(sk.pop())
			if token == '+':
				sk.push(n2 + n1)
			if token == '-':
				sk.push(n2 - n1)
			if token == '*':
				sk.push(n2 * n1)
			if token == '/':
				sk.push(n2 / n1)
			if token == '^':
				sk.push(n2 ** n1)
		else: sk.push(token)#피연산자면
	return sk.top()

# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 3.14*2.10/(10.2-21)
# -0.6105555555555555

# %%
class Stack:
	def __init__(self):
		self.items=[]

	def push(self,val):
		self.items.append(val)
  
	def pop(self):
		try:
			return self.items.pop()
		except IndexError:
			print('Stack is empty')
   
	def top(self):
		return self.items[-1]

	def __len__(self):
		return len(self.items)
  
	def isEmpty(self):
		return self.__len__() == 0
	
def get_token_list(expr):
	expr = expr.replace('+', ' + ').replace('-', ' - ').replace('*', ' * ').replace('/', ' / ').replace('^', ' ^ ').replace('(', ' ( ').replace(')',' ) ')
	token_list = expr.split()
	return token_list
	

def infix_to_postfix(token_list):
    opstack = Stack()
    outstack = []

    prec = {}
    prec['('] = 0
    prec['+'] = 1
    prec['-'] = 1
    prec['*'] = 2
    prec['/'] = 2
    prec['^'] = 3
    prec[')'] = 4

    for token in token_list:
        if token in '=-/*^':
            while not opstack.isEmpty() and opstack.top() != '(' and prec.get(token) <= prec.get(opstack.top()):
                outstack.append(opstack.pop())
            opstack.push(token)
        elif token == '(':
            opstack.push(token)
        elif token == ')':
            while not opstack.isEmpty() and opstack.top() != '(':
                outstack.append(opstack.pop())
            opstack.pop()
        else:
            outstack.append(token)

    #opstack에 남은 모든 연산자를 pop후 outstack에 append
    if not opstack.isEmpty():
        for i in range(len(opstack),0,-1):
            opt = opstack.top()
            opstack.pop()
            outstack.append(opt)
            
    return outstack



def compute_postfix(token_list):
	sk = Stack()
	opstack = Stack()
	for token in token_list:
		if token in '+-/*^':
			n1 = float(sk.pop())
			n2 = float(sk.pop())
			if token == '+':
				sk.push(n2 + n1)
			if token == '-':
				sk.push(n2 - n1)
			if token == '*':
				sk.push(n2 * n1)
			if token == '/':
				sk.push(n2 / n1)
			if token == '^':
				sk.push(n2 ** n1)
		else: sk.push(token)
	return sk.top()

# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 3+ 2* 4/(6- 1)
# Stack is empty
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-6bf5920b1cd1> in <module>
#      87 # 아래 세 줄은 수정하지 말 것!
#      88 expr = input()
# ---> 89 value = compute_postfix(infix_to_postfix(get_token_list(expr)))
#      90 print(value)
#
# <ipython-input-28-6bf5920b1cd1> in compute_postfix(token_list)
#      71                 if token in '+-/*^':
#      72                         n1 = float(sk.pop())
# ---> 73                         n2 = float(sk.pop())
#      74                         if token == '+':
#      75                                 sk.push(n2 + n1)
#
# TypeError: float() argument must be a string or a number, not 'NoneType'

# %%
def infix_to_postfix(token_list):
	opstack = Stack()
	outstack = []

	# 연산자의 우선순위 설정
	prec = {}
	prec['('] = 0
	prec['+'] = 1
	prec['-'] = 1
	prec['*'] = 2
	prec['/'] = 2
	prec['^'] = 3
	prec[')'] = 4

# %%
class Stack:
	def __init__(self):
		self.items=[]

	def push(self,val):
		self.items.append(val)
  
	def pop(self):
		try:
			return self.items.pop()
		except IndexError:
			print('Stack is empty')
   
	def top(self):
		return self.items[-1]

	def __len__(self):
		return len(self.items)
  
	def isEmpty(self):
		return self.__len__() == 0
	
def get_token_list(expr):
	expr = expr.replace('+', ' + ').replace('-', ' - ').replace('*', ' * ').replace('/', ' / ').replace('^', ' ^ ').replace('(', ' ( ').replace(')',' ) ')
	token_list = expr.split()
	return token_list
	
def infix_to_postfix(token_list):
    opstack = Stack()
    outstack = []

    prec = {}
    prec['('] = 0
    prec['+'] = 1
    prec['-'] = 1
    prec['*'] = 2
    prec['/'] = 2
    prec['^'] = 3
    prec[')'] = 4
    
    for token in token_list:	 
        if token == '(':
			opstack.push(token)
		elif token == ')':
			while opstack.top() != '(':
				x = opstack.top()
				opstack.pop()
				outstack.append(x)
			opstack.pop()
		elif token in '+-/*^':
			if opstack.isEmpty():
				opstack.push(token)
			elif opstack.top() == '(':
				opstack.push(token)
			else:
				if prec.get(token) <= prec.get((opstack.top())):
					while prec.get(token) <= prec.get((opstack.top())):
						opt = opstack.top()
						opstack.pop()
						outstack.append(opt)
						if opstack.isEmpty():
							break
					opstack.push(token)
				else:
					opstack.push(token)
		else: # operand일 때
			outstack.append(token)

    #opstack에 남은 모든 연산자를 pop후 outstack에 append
    if not opstack.isEmpty():
        for i in range(len(opstack),0,-1):
            opt = opstack.top()
            opstack.pop()
            outstack.append(opt)
            
    return outstack

def compute_postfix(token_list): #원래 token_list
	X = Stack()
	opstack = Stack()
	for token in token_list:
		if (token != '+') and (token != '-') and (token != '*') and (token != '/') and (token != '^'):
		#if (token in '+-*/^') == False:
			X.push(token)
		else:
			a = float(X.pop())
			b = float(X.pop())
			if token == '+':
				X.push(a+b)
			if token == '-':
				X.push(b-a)
			if token == '*':
			#print(X.pop())
				X.push(a*b)
			#print(X.pop())
			if token == '/':
				X.push(b/a)
			if token == '^':
				X.push(b**a)
	return X.top()
		#print(X.top())
# 아래 세 줄은 수정하지 말 것!
expr = input()
value = compute_postfix(infix_to_postfix(get_token_list(expr)))
print(value)
# Out:
# 3+ 2* 4/(6- 1)
# Stack is empty
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-1cf5b382eb17> in <module>
#      88 # 아래 세 줄은 수정하지 말 것!
#      89 expr = input()
# ---> 90 value = compute_postfix(infix_to_postfix(get_token_list(expr)))
#      91 print(value)
#
# <ipython-input-30-1cf5b382eb17> in compute_postfix(token_list)
#      71                 else:
#      72                         a = float(X.pop())
# ---> 73                         b = float(X.pop())
#      74                         if token == '+':
#      75                                 X.push(a+b)
#
# TypeError: float() argument must be a string or a number, not 'NoneType'
