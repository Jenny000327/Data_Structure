# %% [markdown]
# <a href="https://colab.research.google.com/github/Jenny000327/Data_Structure/blob/main/DS02(%EC%9C%88%EB%8F%84%EC%9A%B0_%EA%B3%84%EC%82%B0%EA%B8%B0_%EC%99%84%EC%84%B1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tkinter import Tk, Label, Button, Entry, StringVar
from functools import partial

# 1. class Stack 정의 
class Stack:
  def __init__(self):
    self.items = []           # 데이터 저장을 위한 리스트 준비
  
  def push(self, val): 
    self.items.append(val)

  def pop(self): 
    try:
      return self.items.pop()  # pop할 아이템이 없으면 
    except IndexError:         # indexError 발생
      print("Stack is empty")

  def top(self): 
    try:
      return self.items[-1] 
    except IndexError:
      print("Stack is empty")

  def __len__(self):            # len()로 호출하면 stack의 item 수 반환
    return len(self.items)
  
  def isEmpty(self): 
    return self.__len__() == 0

# 2. compute_postfix 함수 정의 
def compute_postfix(postfix):
  lst = postfix.split(" ")
  sk = Stack()

  for one in lst:
    # 피연산자이면 
    if one.isdigit():
      sk.push(one)
    # 연산자이면
    elif one in ('+', '-', '*', '/', '^'):
      n1 = str(sk.items.pop())
      n2 = str(sk.items.pop())
      sk.push(eval(n2+one+n1))
    else:
      return '정의되지 않은 연산자입니다.'

  # 소숫점 이하 4자리까지 출력 
  if sk.isEmpty():
    return 'None'
#   return f'{sk.top():.4f}'
  return sk.top()


# 3. infix_to_postfix 함수 정의 
def infix_to_postfix(infix):
  opstack = Stack() # 괄호와 연산자 저장 
  outstack = []  # postfix 수식 
  token_list = infix.split(' ')
  print(token_list)

  # 연산자의 우선순위 설정 
  prec = {}
  prec['('] = 0 
  prec['+'] = 1
  prec['-'] = 1
  prec['*'] = 2  
  prec['/'] = 2 
  prec['^'] = 3 

  for token in token_list:
    if token == '(': # 우선순위 젤 낮음 : 닫힌괄호나와야 출력되도록하기위함 
      opstack.push(token)
    elif token == ')':
      while True:
        x = opstack.pop()
        if x == '(':
          break
        outstack.append(x)
    elif token in '+-/*^':
      # opstack에 있는 자신보다 우선순위가 높거나 같은 연산자는
      #  차례로 모두 pop한 후 outstack에 append함 
      while True:
        x = opstack.top()
        if x is not None and prec[x] >= prec[token]: 
          outstack.append(opstack.pop())
        else:
          break
      opstack.push(token)
    else: # 피연산자 
      outstack.append(token)

  while not opstack.isEmpty():
    outstack.append(opstack.pop())
  
  # opstack 에 남은 모든 연산자를 pop 후 outstack에 append 
  return " ".join(outstack)



def do_something():
    value = compute_postfix(infix_to_postfix(expr.get()))
    total.set("{0:.4f}".format(value))
    return

root = Tk()
root.title("My Calculator")
expr = StringVar()
# title_label = Label(root, text="My Calculator").grid(row=0. columnspan=2)
input_exam = Label(root, text="Space between terms: ( 3 + 2 ) * 8")
exp_entry = Entry(root, textvariable=expr).grid(row=2, column=0)
total_label = Label(root, text="TOTAL").grid(row=3, column=0)
total = StringVar()
total.set('0')
value_label = Label(root, textvariable=total, width=20).grid(row=3, column=1)
equal_btn = Button(root, text=' = ', width=20, command=do_something).grid(row=2, column=1)
root.mainloop()
root.destroy()
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-1-6f1c944d0808> in <module>
#     103     return
#     104
# --> 105 root = Tk()
#     106 root.title("My Calculator")
#     107 expr = StringVar()
#
# /usr/lib/python3.9/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2268                 baseName = baseName + ext
#    2269         interactive = False
# -> 2270         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2271         if useTk:
#    2272             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
